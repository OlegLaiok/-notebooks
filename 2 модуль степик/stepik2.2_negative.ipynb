# %%
# %matplotlib inline
from skimage.io import imread, imsave, imshow
from numpy import clip

# %%
img = imread("tiger-color.png")

# %%
imshow(img)

# %%
img_n = imread("tiger-negative.png")

# %%
imshow(img_n)

# %%
img[0,0], img_n[0,0]
# Out:
# (array([41, 46,  6], dtype=uint8), array([214, 209, 249], dtype=uint8))

# %%
img.max() - img
# Out:
# array([[[214, 209, 249],
#         [223, 218, 255],
#         [223, 219, 255],
#         ...,
#         [253, 253, 255],
#         [252, 253, 255],
#         [253, 254, 255]],
#
#        [[219, 214, 254],
#         [218, 213, 253],
#         [215, 211, 248],
#         ...,
#         [253, 253, 255],
#         [253, 253, 255],
#         [253, 254, 255]],
#
#        [[219, 214, 255],
#         [221, 216, 255],
#         [226, 222, 255],
#         ...,
#         [253, 253, 255],
#         [253, 253, 255],
#         [254, 254, 255]],
#
#        ...,
#
#        [[100, 153, 195],
#         [117, 166, 209],
#         [116, 160, 207],
#         ...,
#         [ 84, 137, 189],
#         [ 92, 145, 197],
#         [105, 158, 210]],
#
#        [[117, 168, 213],
#         [113, 164, 211],
#         [113, 165, 213],
#         ...,
#         [101, 154, 204],
#         [ 98, 151, 203],
#         [ 92, 145, 197]],
#
#        [[116, 166, 215],
#         [108, 160, 210],
#         [108, 166, 216],
# ...
